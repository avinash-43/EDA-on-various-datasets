# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris=pd.read_csv('iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris['Species']=iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
iris.sample(5)
# Out:
# C:\Users\avina\AppData\Local\Temp\ipykernel_3192\546598770.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species']=iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 46    47            5.1           3.8            1.6           0.2        0
# 80    81            5.5           2.4            3.8           1.1        1
# 45    46            4.8           3.0            1.4           0.3        0
# 102  103            7.1           3.0            5.9           2.1        2
# 144  145            6.7           3.3            5.7           2.5        2

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'])
plt.xlabel('sepal length')
plt.ylabel('petal length')
# Out:
# Text(0, 0.5, 'petal length')

# %%
#control the figure size
plt.figure(figsize=(15,7))
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='summer',alpha=.7)
plt.xlabel('sepal length')
plt.ylabel('petal length')
plt.colorbar()

# %%
#annotations
bt=pd.read_csv('batter.csv')
bt
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
df=bt.head(100).sample(25,random_state=5)
df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.scatter(df['avg'],df['strike_rate'])

# %%
#annotation
x=[1,2,3,4]
y=[4,5,6,8]
plt.scatter(x,y)
plt.text(1,4,'point1')
plt.text(2,5,'point2')
plt.text(3,6,'point3')
plt.text(4,8,'point4',fontdict={'size':12,'color':'blue'})
# Out:
# Text(4, 8, 'point4')

# %%
plt.scatter(df['avg'],df['strike_rate'])
for i in range(df.shape[0]):
 plt.text(df['avg'].values[i],df['strike_rate'].values[i],df['batter'].values[i])

# %%
plt.figure(figsize=(18,10))
plt.scatter(df['avg'],df['strike_rate'],s=df['runs'])
for i in range(df.shape[0]):
 plt.text(df['avg'].values[i],df['strike_rate'].values[i],df['batter'].values[i])

# %%
#horizontal and vertical line
plt.figure(figsize=(18,10))
plt.scatter(df['avg'],df['strike_rate'],s=df['runs'])
plt.axhline(130,color='red')
plt.axvline(30,color='red')
for i in range(df.shape[0]):
 plt.text(df['avg'].values[i],df['strike_rate'].values[i],df['batter'].values[i])

# %%
#subplot
bt.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
plt.scatter(bt['avg'],bt['strike_rate'])

# %%
#subplots
fig,ax=plt.subplots()
ax.scatter(bt['avg'],bt['strike_rate'])

# %%
#subplots-.used to plot side by side multiple graphs
fig,ax=plt.subplots()
ax.scatter(bt['avg'],bt['strike_rate'],color='red',marker='+')
ax.set_title('something')
ax.set_xlabel('avg')
ax.set_ylabel('strike rate')
# Out:
# Text(0, 0.5, 'strike rate')

# %%
plt.subplots(nrows=2,ncols=1)
# Out:
# (<Figure size 640x480 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
plt.subplots(nrows=4,ncols=2)
# Out:
# (<Figure size 640x480 with 8 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
fig,ax=plt.subplots(nrows=2,ncols=1,sharex=True,figsize=(10,6))
ax[0].scatter(bt['avg'],bt['strike_rate'],color='red')
ax[1].scatter(bt['avg'],bt['runs'])
ax[0].set_title('avg vs strike rate')
ax[1].set_title('avg vs runs')
ax[0].set_xlabel('avg')
ax[1].set_xlabel('avg')
ax[0].set_ylabel('strike rate')
ax[1].set_ylabel('runs')
# Out:
# Text(0, 0.5, 'runs')

# %%
fig

# %%
ax
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,10))
ax[0,0].scatter(bt['avg'],bt['strike_rate'],color='red')
ax[0,1].scatter(bt['avg'],bt['runs'])
ax[1,0].hist(bt['avg'],color='red')
ax[1,1].hist(bt['avg'])
# Out:
# (array([102., 125., 103.,  82.,  78.,  43.,  22.,  14.,   2.,   1.]),
#  array([ 0.        ,  5.56666667, 11.13333333, 16.7       , 22.26666667,
#         27.83333333, 33.4       , 38.96666667, 44.53333333, 50.1       ,
#         55.66666667]),
#  <BarContainer object of 10 artists>)

# %%
#another method
fig=plt.figure()
ax1=fig.add_subplot(2,1,1)
ax1.scatter(bt['avg'],bt['strike_rate'],color='red')
ax2=fig.add_subplot(2,1,2)
ax2.scatter(bt['avg'],bt['strike_rate'],color='red')

# %%
#3d scatter plot
bt
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
fig=plt.figure()
ax=plt.subplot(projection='3d')
ax.scatter3D(bt['runs'],bt['avg'],bt['strike_rate'])
ax.set_title('IPL batsman analysis')
ax.set_xlabel('runs')
ax.set_ylabel('avg')
ax.set_zlabel('strike_rate')
# Out:
# Text(0.5, 0, 'strike_rate')

# %%
#line plot
x=[0,1,5,25]
y=[0,10,13,0]
z=[0,13,20,9]
fig=plt.figure()
ax=plt.subplot(projection='3d')
ax.scatter3D(x,y,z,s=[100,100,100,100])
ax.plot3D(x,y,z,color='red')

# %%
x=np.linspace(-10,10,100)
y=np.linspace(-10,10,100)
xx,yy=np.meshgrid(x,y)

# %%
z=xx**2+yy**2
z.shape
# Out:
# (100, 100)

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(projection='3d')
p=ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
z=np.sin(xx)+np.cos(yy)
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(projection='3d')
p=ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
#contour plot->it give 3_d to 2-D graph
z=xx**2+yy**2
fig=plt.figure(figsize=(12,8))
ax=plt.subplot()
p=ax.contour(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
#contourf
z=xx**2+yy**2
fig=plt.figure(figsize=(12,8))
ax=plt.subplot()
p=ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
z=np.sin(xx)+np.cos(yy)
fig=plt.figure(figsize=(12,8))
ax=plt.subplot()
p=ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(p)
